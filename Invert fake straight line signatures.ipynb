# %% [markdown]
# # Inverting fake straight lines

# %%
# %matplotlib inline

import torch
import numpy as np
import signatory
import math

import pandas as pd

import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
from insertion import Insertion, get_A_matrix, solve_optimization_problem,invert_signature
from tools import get_signature_as_tensor

# %%
fake_sig = pd.read_csv('data/Fake signature/fake_sig.csv', header=None)

# %%
from mpl_toolkits import mplot3d

for i in np.random.choice(np.arange(0,1000),size=6):
    
    test_sig = torch.tensor(np.array(fake_sig.iloc[i,1:]))
    test_sig = test_sig.view(1,120)
    reconstructed_path=invert_signature(test_sig,3,0,3)
    
    fig,ax = plt.subplots(2,2,figsize=(5,5))
    
    fig.suptitle('Path'+str(i))
    
    ax[0,0] = plt.axes(projection='3d')
    ax[0,0].view_init(0, 10)
    ax[0,0].plot3D(reconstructed_path[0,:], reconstructed_path[1,:], reconstructed_path[2,:],marker='o',linewidth=2, linestyle='--')
    
    plt.savefig('3Dpath3')
    
    plt.show()
    
    ax[0,1] = plt.axes(projection='3d')
    ax[0,1].view_init(0, 20)
    ax[0,1].plot3D(reconstructed_path[0,:], reconstructed_path[1,:], reconstructed_path[2,:],marker='o',linewidth=2,linestyle='--')
    
    plt.show()
    
    ax[1,0] = plt.axes(projection='3d')
    ax[1,0].view_init(40, 20)
    ax[1,0].plot3D(reconstructed_path[0,:], reconstructed_path[1,:], reconstructed_path[2,:],marker='o',linewidth=2,linestyle='--')
    
    plt.show()
    
    ax[1,1] = plt.axes(projection='3d')
    ax[1,1].view_init(30, 20)
    ax[1,1].plot3D(reconstructed_path[0,:], reconstructed_path[1,:], reconstructed_path[2,:],marker='o',linewidth=2,linestyle='--')
    
    plt.show()
